# %%
import pandas as pd
import numpy as np
# import jax
# import jax.numpy as jnp
# from jax import jit

# %%
cpi = pd.read_csv("CPIAUCSL.csv")
#cpi = pd.read_csv("T5YIE.csv")
cpi.columns = ["date", 'CPI_Percent_Change']

# %%
cpi.head()
# Out:
#          date  CPI_Percent_Change
# 0  1947-02-01             0.65177
# 1  1947-03-01             1.75763
# 2  1947-04-01             0.00000
# 3  1947-05-01            -0.22727
# 4  1947-06-01             0.59226

# %%
cpi.shape
# Out:
# (911, 2)

# %%
cpi.date.min()
# Out:
# '1947-02-01'

# %%
cpi[cpi["CPI_Percent_Change"].str.contains(".")]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/rudra/Library/CloudStorage/OneDrive-Personal/Documents/Analytical_Finance_ML/inflation_trading/trading.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/rudra/Library/CloudStorage/OneDrive-Personal/Documents/Analytical_Finance_ML/inflation_trading/trading.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> cpi[cpi["CPI_Percent_Change"].str.contains(".")]
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# Read up on Jax boys, its the future
# https://theaisummer.com/jax/#:~:text=What%20is%20Jax%3F%20Jax%20is%20a%20Python%20library,and%20Deepmind%20teams.%20Source%3A%20JAX%20documentation%20Install%20JAX

# %% [markdown]
# ## Inflation Hedging Portfolio
# In this notebook we will attempt to build a portfolio that hedges against inflation. We will bring in US equities data, and alternative data to do this.

# %% [markdown]
# Alt data ideas:
# - Consumer confience
# - Market sentiment
# - AGRICULTURE
# - Fed data
# - SEC data

# %% [markdown]
# ## Short term goals
# - Explore equity data and make plots related to inflation factors
# - Explore alt data for inflation sentiment or any other factors we want to consider

# %% [markdown]
# ## Long term goal
# - Build a portfolio that does well in high inflation periods
# - Build a portfolio that does well in low inflation periods
# - Predict inflation to reweight the portfolio (We can probably check our Inflation sentiment with the next months CPI,core CPI, or whichever other inflation metric we want to use) (article on this https://www.twosigma.com/articles/forecasting-inflation-like-a-data-scientist-2021-edition/)

# %% [markdown]
# ## CPI Data

# %%
import plotly.express as px
fig = px.line(cpi, x='date', y="CPI_Percent_Change")
fig.show()

# %%
stocks = pd.read_csv("stocks.csv")
# Out:
# /var/folders/m6/h9jtrhyn259fytxp6j9xh9v00000gn/T/ipykernel_2516/3527778674.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   stocks = pd.read_csv("stocks.csv")

# %%
stocks.shape
# Out:
# (4664115, 11)

# %%
stocks["MthCalDt"].max()
# Out:
# '12/31/2021'

# %%
stocks.head()
# Out:
#    PERMNO PrimaryExch                              SecurityNm Ticker  SICCD  \
# 0   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 1   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 2   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 3   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 4   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
#
#   ICBIndustry    MthCalDt  MthPrc    MthRet    MthVol  ShrOut
# 0     NOAVAIL  01/31/1986   4.375  0.707317  177082.0  3680.0
# 1     NOAVAIL  02/28/1986    3.25 -0.257143   82800.0  3680.0
# 2     NOAVAIL  03/31/1986  4.4375  0.365385  107801.0  3680.0
# 3     NOAVAIL  04/30/1986     4.0 -0.098592   95700.0  3793.0
# 4     NOAVAIL  05/30/1986  3.1094 -0.222656  107362.0  3793.0

# %%
stocks.dtypes
# Out:
# PERMNO           int64
# PrimaryExch     object
# SecurityNm      object
# Ticker          object
# SICCD            int64
# ICBIndustry     object
# MthCalDt        object
# MthPrc          object
# MthRet         float64
# MthVol         float64
# ShrOut         float64
# dtype: object

# %%
stocks.columns
# Out:
# Index(['PERMNO', 'PrimaryExch', 'SecurityNm', 'Ticker', 'SICCD', 'ICBIndustry',
#        'MthCalDt', 'MthPrc', 'MthRet', 'MthVol', 'ShrOut'],
#       dtype='object')

# %%
stocks[stocks['PERMNO'] == 44602]
# Out:
#          PERMNO PrimaryExch                                       SecurityNm  \
# 1857671   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857672   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857673   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857674   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857675   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# ...         ...         ...                                              ...
# 1857815   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857816   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857817   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857818   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
# 1857819   44602           Q  INTER CONTINENTAL SERVICES CORP; COM NONE; CONS
#
#         Ticker  SICCD ICBIndustry    MthCalDt  MthPrc    MthRet   MthVol  \
# 1857671   ICSR   7399     NOAVAIL  12/29/1972   2.125  0.062500      NaN
# 1857672   ICSR   7399     NOAVAIL  01/31/1973     2.5  0.176471      NaN
# 1857673   ICSR   7399     NOAVAIL  02/28/1973     2.5  0.000000      NaN
# 1857674   ICSR   7399     NOAVAIL  03/30/1973    1.75 -0.300000      NaN
# 1857675   ICSR   7399     NOAVAIL  04/30/1973  1.9375  0.107143      NaN
# ...        ...    ...         ...         ...     ...       ...      ...
# 1857815   ICSR   7399     NOAVAIL  12/31/1984   2.375  0.187500  16637.0
# 1857816   ICSR   7399     NOAVAIL  01/31/1985   1.625 -0.315789  34000.0
# 1857817   ICSR   7399     NOAVAIL  02/28/1985   1.625  0.000000  18938.0
# 1857818   ICSR   7399     NOAVAIL  03/29/1985    1.25 -0.230769  28400.0
# 1857819   ICSR   7399     NOAVAIL  04/30/1985   1.125 -0.100000   9700.0
#
#          ShrOut
# 1857671   845.0
# 1857672   845.0
# 1857673   845.0
# 1857674   845.0
# 1857675   845.0
# ...         ...
# 1857815  1645.0
# 1857816  1645.0
# 1857817  1645.0
# 1857818  1645.0
# 1857819     NaN
#
# [149 rows x 11 columns]

# %%
temp = stocks['SecurityNm'].sample(n=1).values[0]
fig = px.line(x=stocks[stocks["SecurityNm"] == temp]["MthCalDt"], y=stocks[stocks["SecurityNm"] == temp]["MthRet"])
#44602
print(temp)
fig.show()
# Out:
# AIM IMMUNOTECH INC; COM NONE; CONS

# %%
cpi.dtypes
# Out:
# date                   object
# CPI_Percent_Change    float64
# dtype: object

# %%
from datetime import timedelta

cpi["date"] = pd.to_datetime(cpi["date"]) - timedelta(days=1)

# %%
stocks
# Out:
#          PERMNO PrimaryExch                              SecurityNm Ticker  \
# 0         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 1         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 2         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 3         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 4         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# ...         ...         ...                                     ...    ...
# 4664110   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664111   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664112   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664113   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664114   93436           Q               TESLA INC; COM NONE; CONS   TSLA
#
#          SICCD ICBIndustry    MthCalDt      MthPrc    MthRet       MthVol  \
# 0         3990     NOAVAIL  01/31/1986       4.375  0.707317     177082.0
# 1         3990     NOAVAIL  02/28/1986        3.25 -0.257143      82800.0
# 2         3990     NOAVAIL  03/31/1986      4.4375  0.365385     107801.0
# 3         3990     NOAVAIL  04/30/1986         4.0 -0.098592      95700.0
# 4         3990     NOAVAIL  05/30/1986      3.1094 -0.222656     107362.0
# ...        ...         ...         ...         ...       ...          ...
# 4664110   9999      CONDIS  11/30/2021  1,144.7600  0.027612  645719701.0
# 4664111   9999      CONDIS  12/31/2021  1,056.7800 -0.076855  507511834.0
# 4664112   9999      CONDIS  01/31/2022    936.7200 -0.113609  636164125.0
# 4664113   9999      CONDIS  02/28/2022    870.4300 -0.070768  460954079.0
# 4664114   9999      CONDIS  03/31/2022  1,077.6000  0.238009  574261429.0
#
#             ShrOut
# 0           3680.0
# 1           3680.0
# 2           3680.0
# 3           3793.0
# 4           3793.0
# ...            ...
# 4664110  1004265.0
# 4664111  1033508.0
# 4664112  1033508.0
# 4664113  1033508.0
# 4664114  1035976.0
#
# [4664115 rows x 11 columns]

# %%
stocks.shape
# Out:
# (4664115, 11)

# %%
stocks["MthCalDt"] =pd.to_datetime(stocks["MthCalDt"])

# %%
merged = pd.merge(stocks, cpi, how="left", left_on="MthCalDt", right_on="date")

# %%
merged.shape
# Out:
# (4664115, 13)

# %%
Industry_group=merged.groupby("ICBIndustry").mean()["MthRet"]
px.bar(x=Industry_group.index, y=Industry_group.values)
# Out:
# /var/folders/m6/h9jtrhyn259fytxp6j9xh9v00000gn/T/ipykernel_23589/208143449.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
merged.head()
# Out:
#    PERMNO PrimaryExch                              SecurityNm Ticker  SICCD  \
# 0   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 1   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 2   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 3   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 4   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
#
#   ICBIndustry   MthCalDt  MthPrc    MthRet    MthVol  ShrOut       date  \
# 0     NOAVAIL 1986-01-31   4.375  0.707317  177082.0  3680.0 1986-01-31
# 1     NOAVAIL 1986-02-28    3.25 -0.257143   82800.0  3680.0 1986-02-28
# 2     NOAVAIL 1986-03-31  4.4375  0.365385  107801.0  3680.0 1986-03-31
# 3     NOAVAIL 1986-04-30     4.0 -0.098592   95700.0  3793.0 1986-04-30
# 4     NOAVAIL 1986-05-30  3.1094 -0.222656  107362.0  3793.0        NaT
#
#    CPI_Percent_Change
# 0            -0.18198
# 1            -0.54695
# 2            -0.36664
# 3             0.27599
# 4                 NaN

# %%
thresholds = pd.qcut(merged[merged["CPI_Percent_Change"]>=0]["CPI_Percent_Change"], q=3).unique()

# %%
thresholds
# Out:
# [(0.199, 0.392], (-0.001, 0.199], (0.392, 1.81]]
# Categories (3, interval[float64, right]): [(-0.001, 0.199] < (0.199, 0.392] < (0.392, 1.81]]

# %%
merged["Inflation"] = pd.cut(merged["CPI_Percent_Change"],[-1, 0,.2,.4,5], labels=["deflation","low", "mid", "high"])

# %%
thresholds
# Out:
# [(0.199, 0.392], (-0.001, 0.199], (0.392, 1.81]]
# Categories (3, interval[float64, right]): [(-0.001, 0.199] < (0.199, 0.392] < (0.392, 1.81]]

# %%
merged[merged["Inflation"] == "deflation"]["CPI_Percent_Change"].hist()
# Out:
# <AxesSubplot:>

# %%
merged["Inflation"].value_counts()
# Out:
# mid          1017727
# high          956019
# low           890923
# deflation     404412
# Name: Inflation, dtype: int64

# %%
Industry_Inflation_group=merged.groupby(["ICBIndustry","Inflation"]).mean()["MthRet"]
# Out:
# /var/folders/m6/h9jtrhyn259fytxp6j9xh9v00000gn/T/ipykernel_23589/2053539105.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
#plot a bar graph of the average returns for each industry and inflation level
import plotly.graph_objects as go
fig = go.Figure()
for i in Industry_Inflation_group.index.levels[0]:
    fig.add_trace(go.Bar(x=Industry_Inflation_group[i].index, y=Industry_Inflation_group[i].values, name=i))
fig.show()

# %%
merged
# Out:
#          PERMNO PrimaryExch                              SecurityNm Ticker  \
# 0         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 1         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 2         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 3         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 4         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# ...         ...         ...                                     ...    ...
# 4664110   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664111   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664112   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664113   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664114   93436           Q               TESLA INC; COM NONE; CONS   TSLA
#
#          SICCD ICBIndustry   MthCalDt      MthPrc    MthRet       MthVol  \
# 0         3990     NOAVAIL 1986-01-31       4.375  0.707317     177082.0
# 1         3990     NOAVAIL 1986-02-28        3.25 -0.257143      82800.0
# 2         3990     NOAVAIL 1986-03-31      4.4375  0.365385     107801.0
# 3         3990     NOAVAIL 1986-04-30         4.0 -0.098592      95700.0
# 4         3990     NOAVAIL 1986-05-30      3.1094 -0.222656     107362.0
# ...        ...         ...        ...         ...       ...          ...
# 4664110   9999      CONDIS 2021-11-30  1,144.7600  0.027612  645719701.0
# 4664111   9999      CONDIS 2021-12-31  1,056.7800 -0.076855  507511834.0
# 4664112   9999      CONDIS 2022-01-31    936.7200 -0.113609  636164125.0
# 4664113   9999      CONDIS 2022-02-28    870.4300 -0.070768  460954079.0
# 4664114   9999      CONDIS 2022-03-31  1,077.6000  0.238009  574261429.0
#
#             ShrOut       date  CPI_Percent_Change  Inflation
# 0           3680.0 1986-01-31            -0.18198  deflation
# 1           3680.0 1986-02-28            -0.54695  deflation
# 2           3680.0 1986-03-31            -0.36664  deflation
# 3           3793.0 1986-04-30             0.27599        mid
# 4           3793.0        NaT                 NaN        NaN
# ...            ...        ...                 ...        ...
# 4664110  1004265.0 2021-11-30             0.57517       high
# 4664111  1033508.0 2021-12-31             0.64507       high
# 4664112  1033508.0 2022-01-31             0.79771       high
# 4664113  1033508.0 2022-02-28             1.24075       high
# 4664114  1035976.0 2022-03-31             0.33193        mid
#
# [4664115 rows x 14 columns]

# %%
sic = pd.read_csv("sic.csv")

# %%
stocks['Industry Code'] = stocks["SICCD"].astype(str).str[:2].astype(int)

# %%
industry_codes = pd.read_csv("industry_groups.csv")

# %%
sic.head()
# Out:
#   Division  Major Group  Industry Group  SIC  \
# 0        A            1              11  111
# 1        A            1              11  112
# 2        A            1              11  115
# 3        A            1              11  116
# 4        A            1              11  119
#
#                              Description
# 0                                  Wheat
# 1                                   Rice
# 2                                   Corn
# 3                               Soybeans
# 4  Cash Grains, Not Elsewhere Classified

# %%
sic
# Out:
#      Division  Major Group  Industry Group   SIC  \
# 0           A            1              11   111
# 1           A            1              11   112
# 2           A            1              11   115
# 3           A            1              11   116
# 4           A            1              11   119
# ...       ...          ...             ...   ...
# 1000        J           96             965  9651
# 1001        J           96             966  9661
# 1002        J           97             971  9711
# 1003        J           97             972  9721
# 1004        J           99             999  9999
#
#                                             Description
# 0                                                 Wheat
# 1                                                  Rice
# 2                                                  Corn
# 3                                              Soybeans
# 4                 Cash Grains, Not Elsewhere Classified
# ...                                                 ...
# 1000  Regulation, Licensing, and Inspection of Misce...
# 1001                  Space and Research and Technology
# 1002                                  National Security
# 1003                              International Affairs
# 1004                     Nonclassifiable Establishments
#
# [1005 rows x 5 columns]

# %%
stocks.head()
# Out:
#    PERMNO PrimaryExch                              SecurityNm Ticker  SICCD  \
# 0   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 1   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 2   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 3   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
# 4   10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA   3990
#
#   ICBIndustry   MthCalDt  MthPrc    MthRet    MthVol  ShrOut  Industry Code
# 0     NOAVAIL 1986-01-31   4.375  0.707317  177082.0  3680.0             39
# 1     NOAVAIL 1986-02-28    3.25 -0.257143   82800.0  3680.0             39
# 2     NOAVAIL 1986-03-31  4.4375  0.365385  107801.0  3680.0             39
# 3     NOAVAIL 1986-04-30     4.0 -0.098592   95700.0  3793.0             39
# 4     NOAVAIL 1986-05-30  3.1094 -0.222656  107362.0  3793.0             39

# %%
sic[sic["Major Group"] == 39]
# Out:
#     Division  Major Group  Industry Group   SIC  \
# 556        D           39             391  3911
# 557        D           39             391  3914
# 558        D           39             391  3915
# 559        D           39             393  3931
# 560        D           39             394  3942
# 561        D           39             394  3944
# 562        D           39             394  3949
# 563        D           39             395  3951
# 564        D           39             395  3952
# 565        D           39             395  3953
# 566        D           39             395  3955
# 567        D           39             396  3961
# 568        D           39             396  3965
# 569        D           39             399  3991
# 570        D           39             399  3993
# 571        D           39             399  3995
# 572        D           39             399  3996
# 573        D           39             399  3999
#
#                                            Description
# 556                            Jewelry, Precious Metal
# 557  Silverware, Plated Ware, and Stainless Steel Ware
# 558  Jewelers' Findings and Materials, and Lapidary...
# 559                                Musical Instruments
# 560                             Dolls and Stuffed Toys
# 561  Games, Toys, and Children's Vehicles, Except D...
# 562  Sporting and Athletic Goods, Not Elsewhere Cla...
# 563                Pens, Mechanical Pencils, and Parts
# 564      Lead Pencils, Crayons, and Artists' Materials
# 565                                    Marking Devices
# 566                     Carbon Paper and Inked Ribbons
# 567  Costume Jewelry and Costume Novelties, Except ...
# 568              Fasteners, Buttons, Needles, and Pins
# 569                                 Brooms and Brushes
# 570                  Signs and Advertising Specialties
# 571                                     Burial Caskets
# 572  Linoleum, Asphalted-Felt-Base, and Other Hard ...
# 573  Manufacturing Industries, Not Elsewhere Classi...

# %%
stocks = pd.merge(stocks, sic, left_on="SICCD", right_on="SIC", how="left")
# Out:
#          PERMNO PrimaryExch                              SecurityNm Ticker  \
# 0         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 1         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 2         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 3         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# 4         10000           Q  OPTIMUM MANUFACTURING INC; COM A; CONS  OMFGA
# ...         ...         ...                                     ...    ...
# 4664110   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664111   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664112   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664113   93436           Q               TESLA INC; COM NONE; CONS   TSLA
# 4664114   93436           Q               TESLA INC; COM NONE; CONS   TSLA
#
#          SICCD ICBIndustry   MthCalDt      MthPrc    MthRet       MthVol  \
# 0         3990     NOAVAIL 1986-01-31       4.375  0.707317     177082.0
# 1         3990     NOAVAIL 1986-02-28        3.25 -0.257143      82800.0
# 2         3990     NOAVAIL 1986-03-31      4.4375  0.365385     107801.0
# 3         3990     NOAVAIL 1986-04-30         4.0 -0.098592      95700.0
# 4         3990     NOAVAIL 1986-05-30      3.1094 -0.222656     107362.0
# ...        ...         ...        ...         ...       ...          ...
# 4664110   9999      CONDIS 2021-11-30  1,144.7600  0.027612  645719701.0
# 4664111   9999      CONDIS 2021-12-31  1,056.7800 -0.076855  507511834.0
# 4664112   9999      CONDIS 2022-01-31    936.7200 -0.113609  636164125.0
# 4664113   9999      CONDIS 2022-02-28    870.4300 -0.070768  460954079.0
# 4664114   9999      CONDIS 2022-03-31  1,077.6000  0.238009  574261429.0
#
#             ShrOut  Industry Code Division  Major Group  Industry Group  \
# 0           3680.0             39      NaN          NaN             NaN
# 1           3680.0             39      NaN          NaN             NaN
# 2           3680.0             39      NaN          NaN             NaN
# 3           3793.0             39      NaN          NaN             NaN
# 4           3793.0             39      NaN          NaN             NaN
# ...            ...            ...      ...          ...             ...
# 4664110  1004265.0             99        J         99.0           999.0
# 4664111  1033508.0             99        J         99.0           999.0
# 4664112  1033508.0             99        J         99.0           999.0
# 4664113  1033508.0             99        J         99.0           999.0
# 4664114  1035976.0             99        J         99.0           999.0
#
#             SIC                     Description
# 0           NaN                             NaN
# 1           NaN                             NaN
# 2           NaN                             NaN
# 3           NaN                             NaN
# 4           NaN                             NaN
# ...         ...                             ...
# 4664110  9999.0  Nonclassifiable Establishments
# 4664111  9999.0  Nonclassifiable Establishments
# 4664112  9999.0  Nonclassifiable Establishments
# 4664113  9999.0  Nonclassifiable Establishments
# 4664114  9999.0  Nonclassifiable Establishments
#
# [4664115 rows x 17 columns]

# %%
stocks[stocks["SICCD"] < 1000]["SICCD"].hist()
# Out:
# <AxesSubplot:>

# %%
industry_codes
# Out:
#     Division  Major Group  Industry Group  \
# 0          A            1              11
# 1          A            1              13
# 2          A            1              16
# 3          A            1              17
# 4          A            1              18
# ..       ...          ...             ...
# 411        J           96             965
# 412        J           96             966
# 413        J           97             971
# 414        J           97             972
# 415        J           99             999
#
#                                   Description
# 0                                 Cash Grains
# 1             Field Crops, Except Cash Grains
# 2                       Vegetables And Melons
# 3                        Fruits And Tree Nuts
# 4                   Horticultural Specialties
# ..                                        ...
# 411  Regulation, Licensing, And Inspection Of
# 412             Space Research And Technology
# 413                         National Security
# 414                     International Affairs
# 415            Nonclassifiable Establishments
#
# [416 rows x 4 columns]

# %%
sic
# Out:
#      Division  Major Group  Industry Group   SIC  \
# 0           A            1              11   111
# 1           A            1              11   112
# 2           A            1              11   115
# 3           A            1              11   116
# 4           A            1              11   119
# ...       ...          ...             ...   ...
# 1000        J           96             965  9651
# 1001        J           96             966  9661
# 1002        J           97             971  9711
# 1003        J           97             972  9721
# 1004        J           99             999  9999
#
#                                             Description
# 0                                                 Wheat
# 1                                                  Rice
# 2                                                  Corn
# 3                                              Soybeans
# 4                 Cash Grains, Not Elsewhere Classified
# ...                                                 ...
# 1000  Regulation, Licensing, and Inspection of Misce...
# 1001                  Space and Research and Technology
# 1002                                  National Security
# 1003                              International Affairs
# 1004                     Nonclassifiable Establishments
#
# [1005 rows x 5 columns]

# %%
criteria = [merged['SICCD'].between(1, 3), merged['SICCD'].between(4, 7), merged['SICCD'].between(8, 10)]

values = ["Agriculture, Forestry and Fishing", "Mining", 3]
